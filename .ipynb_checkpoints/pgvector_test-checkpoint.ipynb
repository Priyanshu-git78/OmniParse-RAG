# %%
import psycopg2
import numpy as np
from langchain_huggingface import HuggingFaceEmbeddings


# for correcting the path
from ingestion_pipeline import MultiModalRAG

# %%
retrival= MultiModalRAG()
# Out:
# 2026-07-15 08:09:32.623 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 🔮 Initializing Embeddings:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# 🤖 Initializing Chat Model: Qwen/Qwen2-VL-7B-Instruct-AWQ at http://localhost:8005/v1

# %%
elements = retrival.partition_documents(file_path="test_documents")
chunks = retrival.create_chunks_by_title(elements)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 elements = retrival.partition_documents(file_path="01_company_overview")
#       2 chunks = retrival.create_chunks_by_title(elements)
#       3
#
# File /mnt/hdd/Development Pratice/RAG Industry Level/ingestion_pipeline.py:80, in MultiModalRAG.partition_documents(self, file_path)
#      78 all_elements = []
#      79 target_extensions=(".docx",".xlsx",".csv",".pdf",".pptx")
# ---> 80 for file in files:
#      81     print(f"file exists:{file}")
#      82     if file.lower().endswith(target_extensions):
#
# UnboundLocalError: cannot access local variable 'files' where it is not associated with a value

# %%
conn = psycopg2.connect("dbname=vectorturtorialdb user=pranshu password=ManojUma@78")
cur = conn.cursor()

for
